# %% [markdown]
# # Heart Disease Visualization Analysis

# %% [markdown]
# <p>First we will import the csv files which is used for our analysis and necessary libraries for our analysis</p>

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Configure plots to use light background
plt.style.use('default')
sns.set_style("whitegrid")
sns.set_palette("deep")
plt.rcParams['figure.facecolor'] = 'white'
plt.rcParams['axes.facecolor'] = 'white'

# %%
data = pd.read_csv('heart.csv')

# %%
#lets see the first few rows of the data
data.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %% [markdown]
# <p>About the Columns</p>
# <ol>
# <li>Age: age of the patient [years]</li>
# <li>Sex: sex of the patient [M: Male, F: Female]</li>
# <li>ChestPainType: chest pain type [TA: Typical Angina, ATA: Atypical Angina, NAP: Non-Anginal Pain, ASY: Asymptomatic]</li>
# <li>RestingBP: resting blood pressure [mm Hg]</li>
# <li>Cholesterol: serum cholesterol [mm/dl]</li>
# <li>FastingBS: fasting blood sugar [1: if FastingBS > 120 mg/dl, 0: otherwise]</li>
# <li>RestingECG: resting electrocardiogram results [Normal: Normal, ST: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV), LVH: showing probable or definite left ventricular hypertrophy by Estes' criteria]</li>
# <li>MaxHR: maximum heart rate achieved [Numeric value between 60 and 202]</li>
# <li>ExerciseAngina: exercise-induced angina [Y: Yes, N: No]</li>
# <li>Oldpeak: oldpeak = ST [Numeric value measured in depression]</li>
# <li>ST_Slope: the slope of the peak exercise ST segment [Up: upsloping, Flat: flat, Down: downsloping]</li>
# <li>HeartDisease: output class [1: heart disease, 0: Normal]</li>
#
#
# </ol>

# %%
#now lets look at the columns
data.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Age                 int64
# Sex                object
# ChestPainType      object
# RestingBP           int64
# Cholesterol         int64
# FastingBS           int64
# RestingECG         object
# MaxHR               int64
# ExerciseAngina     object
# Oldpeak           float64
# ST_Slope           object
# HeartDisease        int64
# dtype: object

# %% [markdown]
# ## Lets analyze the dataset like missing values and all since it is from kaggle no need to worry alot

# %%
data.isna().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %% [markdown]
# <p>So no need to worry about outliers, missing values and all</p>

# %% [markdown]
# ## Lets Analyze the Age using the Distplots

# %%
sns.distplot(data['Age'],kde = True,color = 'blue',rug = True)
plt.show()
# Out:
# C:\Users\vijay\AppData\Local\Temp\ipykernel_20572\2309194088.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Age'],kde = True,color = 'blue',rug = True)

# %%
#lets add the bins
sns.distplot(data['Age'],bins = 5,hist_kws={'edgecolor':'black'})
plt.show()
# Out:
# C:\Users\vijay\AppData\Local\Temp\ipykernel_20572\3472386256.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Age'],bins = 5,hist_kws={'edgecolor':'black'})

# %% [markdown]
# <p>So we understood the Males are more affective than the females</p>

# %% [markdown]
# ## Now lets analyze the Resting Blood Pressure

# %%
#lets make a distribution plot
sns.distplot(data['RestingBP'],kde = True,color = 'blue')
# Out:
# C:\Users\vijay\AppData\Local\Temp\ipykernel_20572\2993132243.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['RestingBP'],kde = True,color = 'blue')
# <Axes: xlabel='RestingBP', ylabel='Density'>

# %% [markdown]
# <p>Lets make the distribution of the Cholestrol</p>

# %%
sns.distplot(data['Cholesterol'], kde = True, color = 'blue')
# Out:
# C:\Users\vijay\AppData\Local\Temp\ipykernel_20572\614911618.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Cholesterol'], kde = True, color = 'blue')
# <Axes: xlabel='Cholesterol', ylabel='Density'>

# %% [markdown]
# <p>Here we have the outliers in the Cholesterol also</p>

# %% [markdown]
# ## Lets analyze the Maximum HeartRate

# %%
sns.distplot(data['MaxHR'],kde = True,color = 'black')
plt.show()
# Out:
# C:\Users\vijay\AppData\Local\Temp\ipykernel_20572\3030255844.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['MaxHR'],kde = True,color = 'black')

# %% [markdown]
# ## Lets find for the Fasting Blood Sugar

# %%
#since it is also an numerical variable we can use the distribution plots inorder to analyze it
sns.distplot(data['FastingBS'],kde = True,color = 'Red')
plt.show()
# Out:
# C:\Users\vijay\AppData\Local\Temp\ipykernel_20572\495097517.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['FastingBS'],kde = True,color = 'Red')

# %% [markdown]
# ## Lets analyze the Categorical Columns

# %% [markdown]
# <p>Lets analyze the gender distribution</p>

# %%
data['Sex'].value_counts().plot(kind = 'pie',autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
#how many males and females in the dataset
data.groupby('Sex').size()
# Out:
# Sex
# F    193
# M    725
# dtype: int64

# %% [markdown]
# <p>Females are less that males</p>

# %% [markdown]
# <p>Lets analyze the Chest Pain Type distribution</p>

# %%
data.ChestPainType.value_counts().plot(kind = 'pie',autopct = '%.2f',)
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# <p>Lets analyze the Resting ECG</p>

# %%
data.RestingECG.value_counts(ascending =True)
# Out:
# RestingECG
# ST        178
# LVH       188
# Normal    552
# Name: count, dtype: int64

# %%
data.RestingECG.value_counts().plot(kind = 'pie',autopct = '%.2f')
plt.show()

# %%
data.ST_Slope.value_counts().plot(kind = 'pie',autopct = '%.2f')
plt.show()

# %% [markdown]
# <ol><p>Here it depicts the type of Slope that they got in the ECG checkup</p>
# <li>Nearly 50% of the people in the dataset got flat slope in the ECG test which depicts that they might have heart strain</li>
# <li>43% of the people in the dataset had Upsloping in the ECG test which depicts that they might not expect a heart disease</li>
# <li>Nearly 6.9% of the people in the data had a down sloping in the ECG test which depicts that they might have a serious problem linked to blood flow in the heart</li>
#
# </ol>

# %% [markdown]
# ## Distribution of Heart Disease

# %%
data.HeartDisease.value_counts().plot(kind = 'pie',autopct = '%.2f')
plt.show()

# %% [markdown]
# <p>So nearly 55% of the people who are in the dataset are having the Heart Disease Either Males or Females</p>

# %% [markdown]
# ## Violin Plot

# %%
#this will help you to analyze more than one variable at a time
sns.violinplot(data['Age'])
plt.show()

# %%
sns.violinplot(y = data['Sex'],x = data['HeartDisease'])
plt.show()

# %%
#lets do for the age for the heart disease
sns.violinplot(y = data['Age'],x = data['HeartDisease'])
plt.show()

# %%
#lets analyze the heart disease and resting bp to see the role of resting bp for heart disease
sns.violinplot(y = data['RestingBP'],x = data.HeartDisease)
plt.show()

# %%
#so there is no role of resting bp in the heart disease since it is identical either for the diseased person or non diseased person
sns.violinplot(y = data['Cholesterol'], x = data.HeartDisease)
plt.show()

# %% [markdown]
# ## Heat Map

# %%
#Correlation between the columns where we use the heatmap
data.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
#lets understand the relation between the variables
#to define the correlation between the multiple columns
data.corr(numeric_only=True)
# Out:
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# RestingBP     0.254399   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol  -0.095282   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS     0.198039   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# Age               0.282039
# RestingBP         0.107589
# Cholesterol      -0.232741
# FastingBS         0.267291
# MaxHR            -0.400421
# Oldpeak           0.403951
# HeartDisease      1.000000

# %%
#inorder to avoid that to analyze each and every relation of the columns we can generate a heat map for the correlation
sns.heatmap(data.corr(numeric_only=True))
plt.show()

# %% [markdown]
# <p>Now Analyze the Correlation between the all the things</p>

# %%
sns.jointplot(x = 'HeartDisease',y = 'Oldpeak', data = data)
plt.show()

# %%
sns.jointplot(x = 'Cholesterol',y = 'HeartDisease', data = data,kind = 'hex')
plt.show()

# %%
sns.jointplot(x = 'Age',y = 'HeartDisease', data = data,kind = 'reg',)
plt.show()

# %%
for i,col in enumerate(zip(data['Age'].head(10),data['HeartDisease'].head(10))):
    print(i,col[0],col[1])
# Out:
# 0 40 0
# 1 49 1
# 2 37 0
# 3 48 1
# 4 54 0
# 5 39 0
# 6 45 0
# 7 54 0
# 8 37 1
# 9 48 0
